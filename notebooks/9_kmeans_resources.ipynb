# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

topics = [
    "Linear regression and supervised learning",
    "Neural networks and deep learning",
    "Python loops and functions",
    "Lists dictionaries and tuples in Python"
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(topics)

kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(X)

for topic, cluster in zip(topics, clusters):
    print(cluster, "→", topic)
# Out:
# 0 → Linear regression and supervised learning
# 0 → Neural networks and deep learning
# 1 → Python loops and functions
# 1 → Lists dictionaries and tuples in Python
