# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

texts = [
    "Machine learning is a field of artificial intelligence",
    "Python is widely used for data science",
    "Neural networks learn patterns from data"
]

summaries = [
    "ML is a part of AI",
    "Python is used in data science",
    "Neural networks learn patterns"
]

vectorizer = CountVectorizer(max_features=50)
X = vectorizer.fit_transform(texts).toarray()

y = np.random.rand(len(texts), 10)  # dummy summary vectors

model = Sequential([
    Dense(32, activation="relu", input_shape=(X.shape[1],)),
    Dense(10, activation="sigmoid")
])

model.compile(optimizer="adam", loss="mse")
model.fit(X, y, epochs=20)
# Out:
# c:\Users\prasa\anaconda3\envs\ai_study_pal\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - loss: 0.1150
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1132
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1114
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1097
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1081
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1064
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1048
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1033
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1017
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1002
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0987
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0973
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0959
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0946
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0932
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0919
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0906
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0893
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0881
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0869
